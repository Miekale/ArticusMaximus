# %%
import math

t = [i for i in range(0, 100)]
x = [math.cos(i) for i in t]
y = [math.sin(i) for i in t]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import math
# ----> 3 t = [i for i in range(0, 7, 0.1)]
#       4 x = [math.cos(i) for i in t]
#       5 y = [math.sin(i) for i in t]
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
x
# Out:
# [1.0,
#  0.5403023058681398,
#  -0.4161468365471424,
#  -0.9899924966004454,
#  -0.6536436208636119,
#  0.28366218546322625,
#  0.960170286650366,
#  0.7539022543433046,
#  -0.14550003380861354,
#  -0.9111302618846769,
#  -0.8390715290764524,
#  0.004425697988050785,
#  0.8438539587324921,
#  0.9074467814501962,
#  0.1367372182078336,
#  -0.7596879128588213,
#  -0.9576594803233847,
#  -0.27516333805159693,
#  0.6603167082440802,
#  0.9887046181866692,
#  0.40808206181339196,
#  -0.5477292602242684,
#  -0.9999608263946371,
#  -0.5328330203333975,
#  0.424179007336997,
#  0.9912028118634736,
#  0.6469193223286404,
#  -0.2921388087338362,
#  -0.9626058663135666,
#  -0.7480575296890004,
#  0.15425144988758405,
#  0.9147423578045313,
#  0.8342233605065102,
#  -0.013276747223059479,
#  -0.8485702747846052,
#  -0.9036922050915067,
#  -0.12796368962740468,
#  0.7654140519453434,
#  0.9550736440472949,
#  0.26664293235993725,
#  -0.6669380616522619,
#  -0.9873392775238264,
# ...
